# %%
import pandas as pd

# %% [markdown]
# #### Reading Data using Pandas

# %%
df = pd.read_csv("E:\\Home\\Visualization\\titanic.csv")

# %% [markdown]
# #### Overview of the Data

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who adult_male deck  embark_town alive  alone
# 0    man       True  NaN  Southampton    no  False
# 1  woman      False    C    Cherbourg   yes  False
# 2  woman      False  NaN  Southampton   yes   True
# 3  woman      False    C  Southampton   yes  False
# 4    man       True  NaN  Southampton    no   True

# %% [markdown]
# ### Now Let's take look  at the data graphicially to draw insights

# %% [markdown]
# We will use Seaborn package.
#
# Seaborn is a Python visualization library based on matplotlib. It provides a high-level interface for drawing attractive statistical graphics.Examples can be found here.

# %% [markdown]
# Let us install the seaborn package.
# !pip install seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid", color_codes=True)

# %matplotlib inline

# %%
ax = sns.countplot(x="survived", data=df)

# Setting the title using set_title
ax.set_title("Distribution of Survival")

# %% [markdown]
# ## Let us perform Exploratory Analysis using various plots.

# %% [markdown]
# ### BoxPlot
#
# This kind of plot shows the three quartile values of the distribution along with extreme values. The “whiskers” extend to points that lie within 1.5 IQRs of the lower and upper quartile, and then observations that fall outside this range are displayed independently. Importantly, this means that each value in the boxplot corresponds to an actual observation in the data:

# %%
sns.boxplot(x="survived", y="fare", data=df);

# %% [markdown]
# ### Count Plot
#
# A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable. The basic API and options are identical to those for barplot(), so you can compare counts across nested variables.

# %%
# Show value counts for two categorical variables:
sns.countplot(x="alive",hue="sex",data=df)

# %% [markdown]
# ### Factor Plot
#
# Draw a categorical plot onto a FacetGrid.
#
# The default plot is a point plot, but other seaborn categorical plots can be chosen with the kind parameter, including box plots, violin plots, bar plots, or strip plots.
#
# Make many column facets and wrap them into the rows of the grid

# %%
sns.factorplot("alive", col="deck", col_wrap=3,
                        data=df[df.deck.notnull()],
                        kind="count", size=2.5, aspect=.8)

# %% [markdown]
# ### Bar Plot
# A familiar style of plot that accomplishes this goal is a bar plot. In seaborn, the barplot() function operates on a full dataset and shows an arbitrary estimate, using the mean by default. When there are multiple observations in each category, it also uses bootstrapping to compute a confidence interval around the estimate and plots that using error bars:

# %%
sns.barplot(x="sex", y="survived", hue="pclass", data=df);

# %% [markdown]
# ### Heat Map
#
# Plot rectangular data as a color-encoded matrix.
#
# This function tries to infer a good colormap to use from the data, but this is not guaranteed to work, so we should take care to make sure the kind of colormap (sequential or diverging) and its limits are appropriate.

# %%
# Load the example flights dataset and conver to long-form
flights_long = sns.load_dataset("flights")
flights = flights_long.pivot("month", "year", "passengers")

# Draw a heatmap with the numeric values in each cell
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5)
